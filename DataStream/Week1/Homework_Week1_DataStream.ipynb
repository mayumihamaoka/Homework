# %%
import pandas as pd

# %%
## Using any finance API (we use Yahoo Finance and Tiingo during sessions) 
## download historical stock prices for Google (symbol ‘GOOG’), for the period 1 Jan 2020 to 1 Jan 2021. 

import pandas_datareader as pdr


api_key='76617663fe87274c6562471e9c8bd3ef9cff62e2' # <your OWN API token aka key goes here>


start="2020-1-1"
end="2021-1-1"

df = pdr.tiingo.TiingoDailyReader('GOOG', start=start, end=end, api_key=api_key)

aapl = df.read()

aapl
# Out:
# C:\Users\mayum\miniconda38\lib\site-packages\pandas_datareader\tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   return pd.concat(dfs, self._concat_axis)
#                                     close       high       low      open  \
# symbol date
# GOOG   2020-01-02 00:00:00+00:00  1367.37  1368.1400  1341.550  1341.550
#        2020-01-03 00:00:00+00:00  1360.66  1372.5000  1345.540  1347.860
#        2020-01-06 00:00:00+00:00  1394.21  1396.5000  1350.000  1350.000
#        2020-01-07 00:00:00+00:00  1393.34  1402.9900  1390.380  1397.940
#        2020-01-08 00:00:00+00:00  1404.32  1411.5800  1390.840  1392.080
# ...                                   ...        ...       ...       ...
#        2020-12-24 00:00:00+00:00  1738.85  1746.0000  1729.110  1735.000
#        2020-12-28 00:00:00+00:00  1776.09  1790.7276  1746.335  1751.635
# ...

# %%
##  Save these prices to csv file with Pandas

aapl.to_csv('aapl_historical.csv',  date_format='%Y-%m-%d') # your file paths and file name

##  Read this csv file to display data saved. 

saved_df = pd.read_csv('aapl_historical.csv', header=0, index_col='date', parse_dates=True)

saved_df
# Out:
#            symbol    close       high       low      open   volume  adjClose  \
# date
# 2020-01-02   GOOG  1367.37  1368.1400  1341.550  1341.550  1406731   1367.37
# 2020-01-03   GOOG  1360.66  1372.5000  1345.540  1347.860  1187006   1360.66
# 2020-01-06   GOOG  1394.21  1396.5000  1350.000  1350.000  1733149   1394.21
# 2020-01-07   GOOG  1393.34  1402.9900  1390.380  1397.940  1511693   1393.34
# 2020-01-08   GOOG  1404.32  1411.5800  1390.840  1392.080  1529177   1404.32
# ...           ...      ...        ...       ...       ...      ...       ...
# 2020-12-24   GOOG  1738.85  1746.0000  1729.110  1735.000   346753   1738.85
# 2020-12-28   GOOG  1776.09  1790.7276  1746.335  1751.635  1390962   1776.09
# 2020-12-29   GOOG  1758.72  1792.4400  1756.090  1787.790  1299395   1758.72
# 2020-12-30   GOOG  1739.52  1765.0950  1725.600  1762.010  1306130   1739.52
# 2020-12-31   GOOG  1751.88  1758.9300  1735.420  1735.420  1012240   1751.88
#
# ...

# %%
## Plot a simple diagram to display closing prices for GOOG stock.

import pandas as pd

import matplotlib.pyplot as plt

all_sheets = pd.read_csv('aapl_historical.csv')

google = all_sheets['close'].plot(grid=True, )

plt.show()

# %%
## Using any finance API (we use Yahoo Finance and Tiingo during sessions) 
## download historical stock prices for Google (symbol ‘GOOG’), for the period 1 Jan 2020 to 1 Jan 2021. 

import pandas_datareader as pdr


api_key='76617663fe87274c6562471e9c8bd3ef9cff62e2' # <your OWN API token aka key goes here>


start="2020-1-1"
end="2021-1-1"

msft = pdr.tiingo.TiingoDailyReader('MSFT', start=start, end=end, api_key=api_key)

aapl = msft.read()

aapl
# Out:
# C:\Users\mayum\miniconda38\lib\site-packages\pandas_datareader\tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   return pd.concat(dfs, self._concat_axis)
#                                    close    high     low    open    volume  \
# symbol date
# MSFT   2020-01-02 00:00:00+00:00  160.62  160.73  158.33  158.78  22634546
#        2020-01-03 00:00:00+00:00  158.62  159.95  158.06  158.32  21121681
#        2020-01-06 00:00:00+00:00  159.03  159.10  156.51  157.08  20826702
#        2020-01-07 00:00:00+00:00  157.58  159.67  157.32  159.32  21881740
#        2020-01-08 00:00:00+00:00  160.09  160.80  157.95  158.93  27762026
# ...                                  ...     ...     ...     ...       ...
#        2020-12-24 00:00:00+00:00  222.75  223.61  221.20  221.42  10550572
#        2020-12-28 00:00:00+00:00  224.96  226.03  223.02  224.45  17762701
# ...

# %%
##  Save these prices to csv file with Pandas

aapl.to_csv('historical_msft.csv',  date_format='%Y-%m-%d') # your file paths and file name

##  Read this csv file to display data saved. 

saved_msft = pd.read_csv('historical_msft.csv', header=0, index_col='date', parse_dates=True)

saved_msft
# Out:
#            symbol   close    high     low    open    volume    adjClose  \
# date
# 2020-01-02   MSFT  160.62  160.73  158.33  158.78  22634546  158.207699
# 2020-01-03   MSFT  158.62  159.95  158.06  158.32  21121681  156.237737
# 2020-01-06   MSFT  159.03  159.10  156.51  157.08  20826702  156.641579
# 2020-01-07   MSFT  157.58  159.67  157.32  159.32  21881740  155.213356
# 2020-01-08   MSFT  160.09  160.80  157.95  158.93  27762026  157.685659
# ...           ...     ...     ...     ...     ...       ...         ...
# 2020-12-24   MSFT  222.75  223.61  221.20  221.42  10550572  221.729628
# 2020-12-28   MSFT  224.96  226.03  223.02  224.45  17762701  223.929505
# 2020-12-29   MSFT  224.15  227.18  223.58  226.31  17403213  223.123215
# 2020-12-30   MSFT  221.68  225.63  221.47  225.23  20272337  220.664530
# 2020-12-31   MSFT  222.42  223.00  219.68  221.70  20942132  221.401140
#
#                adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# date
# ...

# %%
## Plot a simple diagram to display closing prices for GOOG stock.

import pandas as pd

import matplotlib.pyplot as plt

sheets = pd.read_csv('historical_msft.csv')

microsoft = sheets['close'].plot(grid=True, )

plt.show()
